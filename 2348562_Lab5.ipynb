# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowmya-2348562/ML-lab/blob/main/2348562_Lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data = pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
print(data.head())
print(data.info())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB
# None

# %%
data.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [5 rows x 21 columns]

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data = data.dropna()

print(data.isnull().sum())
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Identify categorical columns
categorical_columns = data.select_dtypes(include=['object']).columns.tolist()

# Apply one-hot encoding to categorical variables
data = pd.get_dummies(data, columns=categorical_columns)

# %%
data.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  customerID_0002-ORFBO  \
# 0              0       1           29.85                      0
# 1              0      34           56.95                      0
# 2              0       2           53.85                      0
# 3              0      45           42.30                      0
# 4              0       2           70.70                      0
#
#    customerID_0003-MKNFE  customerID_0004-TLHLJ  customerID_0011-IGKFF  \
# 0                      0                      0                      0
# 1                      0                      0                      0
# 2                      0                      0                      0
# 3                      0                      0                      0
# 4                      0                      0                      0
#
#    customerID_0013-EXCHZ  customerID_0013-MHZWF  customerID_0013-SMEOE  ...  \
# 0                      0                      0                      0  ...
# 1                      0                      0                      0  ...
# 2                      0                      0                      0  ...
# 3                      0                      0                      0  ...
# 4                      0                      0                      0  ...
#
#    TotalCharges_996.85  TotalCharges_996.95  TotalCharges_997.65  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    TotalCharges_997.75  TotalCharges_998.1  TotalCharges_999.45  \
# 0                    0                   0                    0
# 1                    0                   0                    0
# 2                    0                   0                    0
# 3                    0                   0                    0
# 4                    0                   0                    0
#
#    TotalCharges_999.8  TotalCharges_999.9  Churn_No  Churn_Yes
# 0                   0                   0         1          0
# 1                   0                   0         1          0
# 2                   0                   0         0          1
# 3                   0                   0         1          0
# 4                   0                   0         0          1
#
# [5 rows x 13620 columns]

# %%
from sklearn.model_selection import train_test_split

X = data.drop('Churn_No', axis=1)  # Features
y = data['Churn_No']  # Target variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

# %%
from sklearn.linear_model import LogisticRegression

# Initialize the logistic regression model
model = LogisticRegression()

# Train the model on the training data
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, cohen_kappa_score, matthews_corrcoef

# Predict on the test data
y_pred = model.predict(X_test)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
kappa = cohen_kappa_score(y_test, y_pred)
mcc = matthews_corrcoef(y_test, y_pred)

# Print the metrics
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-Score: {f1}")
print(f"ROC AUC: {roc_auc}")
print(f"Cohen's Kappa: {kappa}")
print(f"Matthews Correlation Coefficient: {mcc}")
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# ROC AUC: 1.0
# Cohen's Kappa: 1.0
# Matthews Correlation Coefficient: 1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Create a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve

# Get ROC curve values
fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:, 1])

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve

# Get precision-recall curve values
precision, recall, _ = precision_recall_curve(y_test, model.predict_proba(X_test)[:, 1])

# Plot precision-recall curve
plt.figure()
plt.plot(recall, precision, color='darkorange', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.linspace(-6, 6, 100)
y = sigmoid(x)

plt.figure()
plt.plot(x, y, label='Sigmoid Curve')
plt.xlabel('x')
plt.ylabel('Sigmoid(x)')
plt.title('Sigmoid Curve')
plt.axvline(0, color='k', linestyle='--', lw=1)
plt.axhline(0.5, color='r', linestyle='--', lw=1, label='Threshold (0.5)')
plt.legend()
plt.show()

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10]}  # Reduce the range of C values

# %%
# Example: Subsample 20% of the data
import random

random.seed(42)  # Set a seed for reproducibility
sample_indices = random.sample(range(len(X_train)), int(0.2 * len(X_train)))
X_train_sampled = X_train.iloc[sample_indices]
y_train_sampled = y_train.iloc[sample_indices]

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, y_train)

high_risk_customers = model.predict(X_test)

for customer_id, churn_probability in zip(X_test.index, high_risk_customers):
    if churn_probability > 0.5:
        print(f"Send personalized offer to customer {customer_id} to retain them.")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Send personalized offer to customer 3678 to retain them.
# Send personalized offer to customer 4060 to retain them.
# Send personalized offer to customer 5007 to retain them.
# Send personalized offer to customer 2603 to retain them.
# Send personalized offer to customer 6910 to retain them.
# Send personalized offer to customer 1672 to retain them.
# Send personalized offer to customer 4176 to retain them.
# Send personalized offer to customer 391 to retain them.
# Send personalized offer to customer 521 to retain them.
# Send personalized offer to customer 472 to retain them.
# Send personalized offer to customer 1553 to retain them.
# Send personalized offer to customer 2209 to retain them.
# Send personalized offer to customer 6646 to retain them.
# Send personalized offer to customer 4001 to retain them.
# Send personalized offer to customer 1145 to retain them.
# Send personalized offer to customer 3210 to retain them.
# Send personalized offer to customer 1684 to retain them.
# Send personalized offer to customer 7024 to retain them.
# Send personalized offer to customer 3941 to retain them.
# Send personalized offer to customer 2796 to retain them.
# Send personalized offer to customer 3880 to retain them.
# Send personalized offer to customer 4378 to retain them.
# Send personalized offer to customer 4639 to retain them.
# Send personalized offer to customer 2714 to retain them.
# Send personalized offer to customer 6892 to retain them.
# Send personalized offer to customer 5452 to retain them.
# Send personalized offer to customer 661 to retain them.
# Send personalized offer to customer 5281 to retain them.
# Send personalized offer to customer 671 to retain them.
# Send personalized offer to customer 194 to retain them.
# Send personalized offer to customer 3701 to retain them.
# Send personalized offer to customer 3449 to retain them.
# Send personalized offer to customer 1221 to retain them.
# Send personalized offer to customer 2240 to retain them.
# Send personalized offer to customer 6960 to retain them.
# Send personalized offer to customer 3314 to retain them.
# Send personalized offer to customer 3321 to retain them.
# Send personalized offer to customer 6798 to retain them.
# Send personalized offer to customer 604 to retain them.
# Send personalized offer to customer 6454 to retain them.
# Send personalized offer to customer 6200 to retain them.
# Send personalized offer to customer 2937 to retain them.
# Send personalized offer to customer 6977 to retain them.
# Send personalized offer to customer 3220 to retain them.
# Send personalized offer to customer 1017 to retain them.
# Send personalized offer to customer 3860 to retain them.
# Send personalized offer to customer 1290 to retain them.
# Send personalized offer to customer 4861 to retain them.
# Send personalized offer to customer 2439 to retain them.
# Send personalized offer to customer 942 to retain them.
# Send personalized offer to customer 4652 to retain them.
# Send personalized offer to customer 6756 to retain them.
# Send personalized offer to customer 5353 to retain them.
# Send personalized offer to customer 2264 to retain them.
# Send personalized offer to customer 4187 to retain them.
# Send personalized offer to customer 2569 to retain them.
# Send personalized offer to customer 4026 to retain them.
# Send personalized offer to customer 6579 to retain them.
# Send personalized offer to customer 2299 to retain them.
# Send personalized offer to customer 4958 to retain them.
# Send personalized offer to customer 497 to retain them.
# Send personalized offer to customer 1241 to retain them.
# Send personalized offer to customer 2509 to retain them.
# Send personalized offer to customer 1900 to retain them.
# Send personalized offer to customer 500 to retain them.
# Send personalized offer to customer 877 to retain them.
# Send personalized offer to customer 4467 to retain them.
# Send personalized offer to customer 2898 to retain them.
# Send personalized offer to customer 1873 to retain them.
# Send personalized offer to customer 145 to retain them.
# Send personalized offer to customer 3304 to retain them.
# Send personalized offer to customer 2118 to retain them.
# Send personalized offer to customer 1064 to retain them.
# Send personalized offer to customer 2399 to retain them.
# Send personalized offer to customer 1230 to retain them.
# Send personalized offer to customer 1766 to retain them.
# Send personalized offer to customer 4650 to retain them.
# Send personalized offer to customer 4782 to retain them.
# Send personalized offer to customer 2604 to retain them.
# Send personalized offer to customer 6072 to retain them.
# Send personalized offer to customer 1758 to retain them.
# Send personalized offer to customer 273 to retain them.
# Send personalized offer to customer 1195 to retain them.
# Send personalized offer to customer 1946 to retain them.
# Send personalized offer to customer 6676 to retain them.
# Send personalized offer to customer 838 to retain them.
# Send personalized offer to customer 6029 to retain them.
# Send personalized offer to customer 1034 to retain them.
# Send personalized offer to customer 6540 to retain them.
# Send personalized offer to customer 586 to retain them.
# Send personalized offer to customer 5660 to retain them.
# Send personalized offer to customer 379 to retain them.
# Send personalized offer to customer 6774 to retain them.
# Send personalized offer to customer 2280 to retain them.
# Send personalized offer to customer 4010 to retain them.
# Send personalized offer to customer 6487 to retain them.
# Send personalized offer to customer 2991 to retain them.
# Send personalized offer to customer 2524 to retain them.
# Send personalized offer to customer 2601 to retain them.
# Send personalized offer to customer 3569 to retain them.
# Send personalized offer to customer 5305 to retain them.
# Send personalized offer to customer 4302 to retain them.
# Send personalized offer to customer 3323 to retain them.
# Send personalized offer to customer 2858 to retain them.
# Send personalized offer to customer 1797 to retain them.
# Send personalized offer to customer 4196 to retain them.
# Send personalized offer to customer 3478 to retain them.
# Send personalized offer to customer 5809 to retain them.
# Send personalized offer to customer 1957 to retain them.
# Send personalized offer to customer 5404 to retain them.
# Send personalized offer to customer 6592 to retain them.
# Send personalized offer to customer 1228 to retain them.
# Send personalized offer to customer 6188 to retain them.
# Send personalized offer to customer 4401 to retain them.
# Send personalized offer to customer 5619 to retain them.
# Send personalized offer to customer 2530 to retain them.
# Send personalized offer to customer 4382 to retain them.
# Send personalized offer to customer 6020 to retain them.
# Send personalized offer to customer 4034 to retain them.
# Send personalized offer to customer 2878 to retain them.
# Send personalized offer to customer 5267 to retain them.
# Send personalized offer to customer 367 to retain them.
# Send personalized offer to customer 6555 to retain them.
# Send personalized offer to customer 5202 to retain them.
# Send personalized offer to customer 6934 to retain them.
# Send personalized offer to customer 4102 to retain them.
# Send personalized offer to customer 2660 to retain them.
# Send personalized offer to customer 2079 to retain them.
# Send personalized offer to customer 6124 to retain them.
# Send personalized offer to customer 4053 to retain them.
# Send personalized offer to customer 3809 to retain them.
# Send personalized offer to customer 4791 to retain them.
# Send personalized offer to customer 2233 to retain them.
# Send personalized offer to customer 887 to retain them.
# Send personalized offer to customer 1590 to retain them.
# Send personalized offer to customer 37 to retain them.
# Send personalized offer to customer 2321 to retain them.
# Send personalized offer to customer 885 to retain them.
# Send personalized offer to customer 4376 to retain them.
# Send personalized offer to customer 5709 to retain them.
# Send personalized offer to customer 6604 to retain them.
# Send personalized offer to customer 4870 to retain them.
# Send personalized offer to customer 5533 to retain them.
# Send personalized offer to customer 1317 to retain them.
# Send personalized offer to customer 4433 to retain them.
# Send personalized offer to customer 4454 to retain them.
# Send personalized offer to customer 1764 to retain them.
# Send personalized offer to customer 2602 to retain them.
# Send personalized offer to customer 3214 to retain them.
# Send personalized offer to customer 1289 to retain them.
# Send personalized offer to customer 186 to retain them.
# Send personalized offer to customer 3974 to retain them.
# Send personalized offer to customer 2658 to retain them.
# Send personalized offer to customer 4456 to retain them.
# Send personalized offer to customer 5080 to retain them.
# Send personalized offer to customer 814 to retain them.
# Send personalized offer to customer 3118 to retain them.
# Send personalized offer to customer 2402 to retain them.
# Send personalized offer to customer 6585 to retain them.
# Send personalized offer to customer 380 to retain them.
# Send personalized offer to customer 6959 to retain them.
# Send personalized offer to customer 4646 to retain them.
# Send personalized offer to customer 6631 to retain them.
# Send personalized offer to customer 5092 to retain them.
# Send personalized offer to customer 2219 to retain them.
# Send personalized offer to customer 4304 to retain them.
# Send personalized offer to customer 4197 to retain them.
# Send personalized offer to customer 621 to retain them.
# Send personalized offer to customer 1915 to retain them.
# Send personalized offer to customer 1892 to retain them.
# Send personalized offer to customer 953 to retain them.
# Send personalized offer to customer 4858 to retain them.
# Send personalized offer to customer 5302 to retain them.
# Send personalized offer to customer 4050 to retain them.
# Send personalized offer to customer 6682 to retain them.
# Send personalized offer to customer 2394 to retain them.
# Send personalized offer to customer 4178 to retain them.
# Send personalized offer to customer 5973 to retain them.
# Send personalized offer to customer 1591 to retain them.
# Send personalized offer to customer 2546 to retain them.
# Send personalized offer to customer 5148 to retain them.
# Send personalized offer to customer 5176 to retain them.
# Send personalized offer to customer 6404 to retain them.
# Send personalized offer to customer 2906 to retain them.
# Send personalized offer to customer 5667 to retain them.
# Send personalized offer to customer 3017 to retain them.
# Send personalized offer to customer 3005 to retain them.
# Send personalized offer to customer 1116 to retain them.
# Send personalized offer to customer 130 to retain them.
# Send personalized offer to customer 458 to retain them.
# Send personalized offer to customer 1146 to retain them.
# Send personalized offer to customer 3370 to retain them.
# Send personalized offer to customer 2078 to retain them.
# Send personalized offer to customer 6987 to retain them.
# Send personalized offer to customer 3611 to retain them.
# Send personalized offer to customer 368 to retain them.
# Send personalized offer to customer 6624 to retain them.
# Send personalized offer to customer 2254 to retain them.
# Send personalized offer to customer 129 to retain them.
# Send personalized offer to customer 7007 to retain them.
# Send personalized offer to customer 5352 to retain them.
# Send personalized offer to customer 2072 to retain them.
# Send personalized offer to customer 1757 to retain them.
# Send personalized offer to customer 916 to retain them.
# Send personalized offer to customer 5376 to retain them.
# Send personalized offer to customer 2138 to retain them.
# Send personalized offer to customer 2187 to retain them.
# Send personalized offer to customer 2183 to retain them.
# Send personalized offer to customer 4599 to retain them.
# Send personalized offer to customer 2764 to retain them.
# Send personalized offer to customer 584 to retain them.
# Send personalized offer to customer 6712 to retain them.
# Send personalized offer to customer 5835 to retain them.
# Send personalized offer to customer 2218 to retain them.
# Send personalized offer to customer 5434 to retain them.
# Send personalized offer to customer 2692 to retain them.
# Send personalized offer to customer 4099 to retain them.
# Send personalized offer to customer 1330 to retain them.
# Send personalized offer to customer 2210 to retain them.
# Send personalized offer to customer 6399 to retain them.
# Send personalized offer to customer 6099 to retain them.
# Send personalized offer to customer 2234 to retain them.
# Send personalized offer to customer 3307 to retain them.
# Send personalized offer to customer 959 to retain them.
# Send personalized offer to customer 6826 to retain them.
# Send personalized offer to customer 1912 to retain them.
# Send personalized offer to customer 4279 to retain them.
# Send personalized offer to customer 4809 to retain them.
# Send personalized offer to customer 5604 to retain them.
# Send personalized offer to customer 62 to retain them.
# Send personalized offer to customer 6014 to retain them.
# Send personalized offer to customer 6510 to retain them.
# Send personalized offer to customer 103 to retain them.
# Send personalized offer to customer 5221 to retain them.
# Send personalized offer to customer 4047 to retain them.
# Send personalized offer to customer 1128 to retain them.
# Send personalized offer to customer 6706 to retain them.
# Send personalized offer to customer 1398 to retain them.
# Send personalized offer to customer 5304 to retain them.
# Send personalized offer to customer 925 to retain them.
# Send personalized offer to customer 4242 to retain them.
# Send personalized offer to customer 1527 to retain them.
# Send personalized offer to customer 1030 to retain them.
# Send personalized offer to customer 88 to retain them.
# Send personalized offer to customer 681 to retain them.
# Send personalized offer to customer 256 to retain them.
# Send personalized offer to customer 3515 to retain them.
# Send personalized offer to customer 740 to retain them.
# Send personalized offer to customer 1606 to retain them.
# Send personalized offer to customer 606 to retain them.
# Send personalized offer to customer 1336 to retain them.
# Send personalized offer to customer 2015 to retain them.
# Send personalized offer to customer 5271 to retain them.
# Send personalized offer to customer 2548 to retain them.
# Send personalized offer to customer 6513 to retain them.
# Send personalized offer to customer 3519 to retain them.
# Send personalized offer to customer 291 to retain them.
# Send personalized offer to customer 2238 to retain them.
# Send personalized offer to customer 3348 to retain them.
# Send personalized offer to customer 4779 to retain them.
# Send personalized offer to customer 994 to retain them.
# Send personalized offer to customer 2477 to retain them.
# Send personalized offer to customer 5002 to retain them.
# Send personalized offer to customer 5445 to retain them.
# Send personalized offer to customer 1723 to retain them.
# Send personalized offer to customer 6958 to retain them.
# Send personalized offer to customer 1031 to retain them.
# Send personalized offer to customer 2389 to retain them.
# Send personalized offer to customer 5919 to retain them.
# Send personalized offer to customer 6353 to retain them.
# Send personalized offer to customer 6694 to retain them.
# Send personalized offer to customer 2478 to retain them.
# Send personalized offer to customer 5325 to retain them.
# Send personalized offer to customer 4032 to retain them.
# Send personalized offer to customer 3804 to retain them.
# Send personalized offer to customer 2387 to retain them.
# Send personalized offer to customer 6042 to retain them.
# Send personalized offer to customer 3814 to retain them.
# Send personalized offer to customer 6389 to retain them.
# Send personalized offer to customer 5529 to retain them.
# Send personalized offer to customer 6645 to retain them.
# Send personalized offer to customer 3566 to retain them.
# Send personalized offer to customer 3998 to retain them.
# Send personalized offer to customer 6788 to retain them.
# Send personalized offer to customer 4371 to retain them.
# Send personalized offer to customer 2872 to retain them.
# Send personalized offer to customer 3865 to retain them.
# Send personalized offer to customer 1636 to retain them.
# Send personalized offer to customer 1804 to retain them.
# Send personalized offer to customer 5184 to retain them.
# Send personalized offer to customer 2538 to retain them.
# Send personalized offer to customer 4620 to retain them.
# Send personalized offer to customer 3823 to retain them.
# Send personalized offer to customer 1668 to retain them.
# Send personalized offer to customer 562 to retain them.
# Send personalized offer to customer 6721 to retain them.
# Send personalized offer to customer 649 to retain them.
# Send personalized offer to customer 6063 to retain them.
# Send personalized offer to customer 2377 to retain them.
# Send personalized offer to customer 5820 to retain them.
# Send personalized offer to customer 2152 to retain them.
# Send personalized offer to customer 2842 to retain them.
# Send personalized offer to customer 246 to retain them.
# Send personalized offer to customer 5897 to retain them.
# Send personalized offer to customer 4647 to retain them.
# Send personalized offer to customer 3460 to retain them.
# Send personalized offer to customer 4274 to retain them.
# Send personalized offer to customer 6685 to retain them.
# Send personalized offer to customer 128 to retain them.
# Send personalized offer to customer 202 to retain them.
# Send personalized offer to customer 2106 to retain them.
# Send personalized offer to customer 565 to retain them.
# Send personalized offer to customer 3 to retain them.
# Send personalized offer to customer 6615 to retain them.
# Send personalized offer to customer 2450 to retain them.
# Send personalized offer to customer 5152 to retain them.
# Send personalized offer to customer 1100 to retain them.
# Send personalized offer to customer 4627 to retain them.
# Send personalized offer to customer 4344 to retain them.
# Send personalized offer to customer 4364 to retain them.
# Send personalized offer to customer 32 to retain them.
# Send personalized offer to customer 2767 to retain them.
# Send personalized offer to customer 6595 to retain them.
# Send personalized offer to customer 338 to retain them.
# Send personalized offer to customer 4077 to retain them.
# Send personalized offer to customer 1669 to retain them.
# Send personalized offer to customer 4560 to retain them.
# Send personalized offer to customer 954 to retain them.
# Send personalized offer to customer 6951 to retain them.
# Send personalized offer to customer 3191 to retain them.
# Send personalized offer to customer 6308 to retain them.
# Send personalized offer to customer 1619 to retain them.
# Send personalized offer to customer 2553 to retain them.
# Send personalized offer to customer 4600 to retain them.
# Send personalized offer to customer 5260 to retain them.
# Send personalized offer to customer 2935 to retain them.
# Send personalized offer to customer 1374 to retain them.
# Send personalized offer to customer 2344 to retain them.
# Send personalized offer to customer 2910 to retain them.
# Send personalized offer to customer 6201 to retain them.
# Send personalized offer to customer 6450 to retain them.
# Send personalized offer to customer 5769 to retain them.
# Send personalized offer to customer 1156 to retain them.
# Send personalized offer to customer 2853 to retain them.
# Send personalized offer to customer 7016 to retain them.
# Send personalized offer to customer 3960 to retain them.
# Send personalized offer to customer 1752 to retain them.
# Send personalized offer to customer 2803 to retain them.
# Send personalized offer to customer 1394 to retain them.
# Send personalized offer to customer 1945 to retain them.
# Send personalized offer to customer 2325 to retain them.
# Send personalized offer to customer 460 to retain them.
# Send personalized offer to customer 3488 to retain them.
# Send personalized offer to customer 4572 to retain them.
# Send personalized offer to customer 1287 to retain them.
# Send personalized offer to customer 5521 to retain them.
# Send personalized offer to customer 2064 to retain them.
# Send personalized offer to customer 4151 to retain them.
# Send personalized offer to customer 2068 to retain them.
# Send personalized offer to customer 4210 to retain them.
# Send personalized offer to customer 4904 to retain them.
# Send personalized offer to customer 4496 to retain them.
# Send personalized offer to customer 829 to retain them.
# Send personalized offer to customer 3072 to retain them.
# Send personalized offer to customer 1350 to retain them.
# Send personalized offer to customer 6442 to retain them.
# Send personalized offer to customer 5396 to retain them.
# Send personalized offer to customer 5736 to retain them.
# Send personalized offer to customer 1301 to retain them.
# Send personalized offer to customer 1367 to retain them.
# Send personalized offer to customer 15 to retain them.
# Send personalized offer to customer 1168 to retain them.
# Send personalized offer to customer 1139 to retain them.
# Send personalized offer to customer 2081 to retain them.
# Send personalized offer to customer 2382 to retain them.
# Send personalized offer to customer 4289 to retain them.
# Send personalized offer to customer 6948 to retain them.
# Send personalized offer to customer 4020 to retain them.
# Send personalized offer to customer 6419 to retain them.
# Send personalized offer to customer 2657 to retain them.
# Send personalized offer to customer 2400 to retain them.
# Send personalized offer to customer 3219 to retain them.
# Send personalized offer to customer 5129 to retain them.
# Send personalized offer to customer 2328 to retain them.
# Send personalized offer to customer 5496 to retain them.
# Send personalized offer to customer 4111 to retain them.
# Send personalized offer to customer 125 to retain them.
# Send personalized offer to customer 3833 to retain them.
# Send personalized offer to customer 81 to retain them.
# Send personalized offer to customer 1962 to retain them.
# Send personalized offer to customer 4953 to retain them.
# Send personalized offer to customer 558 to retain them.
# Send personalized offer to customer 3343 to retain them.
# Send personalized offer to customer 2558 to retain them.
# Send personalized offer to customer 369 to retain them.
# Send personalized offer to customer 40 to retain them.
# Send personalized offer to customer 4493 to retain them.
# Send personalized offer to customer 6245 to retain them.
# Send personalized offer to customer 1019 to retain them.
# Send personalized offer to customer 4571 to retain them.
# Send personalized offer to customer 5974 to retain them.
# Send personalized offer to customer 3629 to retain them.
# Send personalized offer to customer 6783 to retain them.
# Send personalized offer to customer 2310 to retain them.
# Send personalized offer to customer 5582 to retain them.
# Send personalized offer to customer 1239 to retain them.
# Send personalized offer to customer 5558 to retain them.
# Send personalized offer to customer 1737 to retain them.
# Send personalized offer to customer 6008 to retain them.
# Send personalized offer to customer 1794 to retain them.
# Send personalized offer to customer 6920 to retain them.
# Send personalized offer to customer 1182 to retain them.
# Send personalized offer to customer 3546 to retain them.
# Send personalized offer to customer 3399 to retain them.
# Send personalized offer to customer 5417 to retain them.
# Send personalized offer to customer 5478 to retain them.
# Send personalized offer to customer 5278 to retain them.
# Send personalized offer to customer 6112 to retain them.
# Send personalized offer to customer 5218 to retain them.
# Send personalized offer to customer 6471 to retain them.
# Send personalized offer to customer 1067 to retain them.
# Send personalized offer to customer 6737 to retain them.
# Send personalized offer to customer 5705 to retain them.
# Send personalized offer to customer 6485 to retain them.
# Send personalized offer to customer 1630 to retain them.
# Send personalized offer to customer 6326 to retain them.
# Send personalized offer to customer 6859 to retain them.
# Send personalized offer to customer 2998 to retain them.
# Send personalized offer to customer 3022 to retain them.
# Send personalized offer to customer 2318 to retain them.
# Send personalized offer to customer 3469 to retain them.
# Send personalized offer to customer 5142 to retain them.
# Send personalized offer to customer 1939 to retain them.
# Send personalized offer to customer 5448 to retain them.
# Send personalized offer to customer 6707 to retain them.
# Send personalized offer to customer 2725 to retain them.
# Send personalized offer to customer 6136 to retain them.
# Send personalized offer to customer 6250 to retain them.
# Send personalized offer to customer 4595 to retain them.
# Send personalized offer to customer 6255 to retain them.
# Send personalized offer to customer 1112 to retain them.
# Send personalized offer to customer 6912 to retain them.
# Send personalized offer to customer 2220 to retain them.
# Send personalized offer to customer 2750 to retain them.
# Send personalized offer to customer 1411 to retain them.
# Send personalized offer to customer 1932 to retain them.
# Send personalized offer to customer 6644 to retain them.
# Send personalized offer to customer 2416 to retain them.
# Send personalized offer to customer 5349 to retain them.
# Send personalized offer to customer 4507 to retain them.
# Send personalized offer to customer 1614 to retain them.
# Send personalized offer to customer 6297 to retain them.
# Send personalized offer to customer 6472 to retain them.
# Send personalized offer to customer 5240 to retain them.
# Send personalized offer to customer 5235 to retain them.
# Send personalized offer to customer 4747 to retain them.
# Send personalized offer to customer 3560 to retain them.
# Send personalized offer to customer 3901 to retain them.
# Send personalized offer to customer 6430 to retain them.
# Send personalized offer to customer 4656 to retain them.
# Send personalized offer to customer 2090 to retain them.
# Send personalized offer to customer 6260 to retain them.
# Send personalized offer to customer 1637 to retain them.
# Send personalized offer to customer 727 to retain them.
# Send personalized offer to customer 2661 to retain them.
# Send personalized offer to customer 4142 to retain them.
# Send personalized offer to customer 4510 to retain them.
# Send personalized offer to customer 4303 to retain them.
# Send personalized offer to customer 2475 to retain them.
# Send personalized offer to customer 6208 to retain them.
# Send personalized offer to customer 1455 to retain them.
# Send personalized offer to customer 1022 to retain them.
# Send personalized offer to customer 2391 to retain them.
# Send personalized offer to customer 6303 to retain them.
# Send personalized offer to customer 4584 to retain them.
# Send personalized offer to customer 6295 to retain them.
# Send personalized offer to customer 5108 to retain them.
# Send personalized offer to customer 1638 to retain them.
# Send personalized offer to customer 1735 to retain them.
# Send personalized offer to customer 3513 to retain them.
# Send personalized offer to customer 4838 to retain them.
# Send personalized offer to customer 2834 to retain them.
# Send personalized offer to customer 5324 to retain them.
# Send personalized offer to customer 2832 to retain them.
# Send personalized offer to customer 4905 to retain them.
# Send personalized offer to customer 363 to retain them.
# Send personalized offer to customer 2866 to retain them.
# Send personalized offer to customer 2650 to retain them.
# Send personalized offer to customer 2685 to retain them.
# Send personalized offer to customer 6688 to retain them.
# Send personalized offer to customer 4484 to retain them.
# Send personalized offer to customer 3944 to retain them.
# Send personalized offer to customer 3112 to retain them.
# Send personalized offer to customer 3602 to retain them.
# Send personalized offer to customer 4158 to retain them.
# Send personalized offer to customer 2420 to retain them.
# Send personalized offer to customer 849 to retain them.
# Send personalized offer to customer 6140 to retain them.
# Send personalized offer to customer 2583 to retain them.
# Send personalized offer to customer 204 to retain them.
# Send personalized offer to customer 5398 to retain them.
# Send personalized offer to customer 4796 to retain them.
# Send personalized offer to customer 1167 to retain them.
# Send personalized offer to customer 6429 to retain them.
# Send personalized offer to customer 2476 to retain them.
# Send personalized offer to customer 6898 to retain them.
# Send personalized offer to customer 866 to retain them.
# Send personalized offer to customer 701 to retain them.
# Send personalized offer to customer 6909 to retain them.
# Send personalized offer to customer 5731 to retain them.
# Send personalized offer to customer 5054 to retain them.
# Send personalized offer to customer 6411 to retain them.
# Send personalized offer to customer 626 to retain them.
# Send personalized offer to customer 7014 to retain them.
# Send personalized offer to customer 2647 to retain them.
# Send personalized offer to customer 2947 to retain them.
# Send personalized offer to customer 4470 to retain them.
# Send personalized offer to customer 2675 to retain them.
# Send personalized offer to customer 4175 to retain them.
# Send personalized offer to customer 1219 to retain them.
# Send personalized offer to customer 4061 to retain them.
# Send personalized offer to customer 6361 to retain them.
# Send personalized offer to customer 3839 to retain them.
# Send personalized offer to customer 6298 to retain them.
# Send personalized offer to customer 3390 to retain them.
# Send personalized offer to customer 1209 to retain them.
# Send personalized offer to customer 3084 to retain them.
# Send personalized offer to customer 201 to retain them.
# Send personalized offer to customer 4704 to retain them.
# Send personalized offer to customer 5818 to retain them.
# Send personalized offer to customer 6565 to retain them.
# Send personalized offer to customer 1229 to retain them.
# Send personalized offer to customer 6292 to retain them.
# Send personalized offer to customer 1500 to retain them.
# Send personalized offer to customer 739 to retain them.
# Send personalized offer to customer 5292 to retain them.
# Send personalized offer to customer 2883 to retain them.
# Send personalized offer to customer 3754 to retain them.
# Send personalized offer to customer 3896 to retain them.
# Send personalized offer to customer 2436 to retain them.
# Send personalized offer to customer 3281 to retain them.
# Send personalized offer to customer 5548 to retain them.
# Send personalized offer to customer 1272 to retain them.
# Send personalized offer to customer 3435 to retain them.
# Send personalized offer to customer 4064 to retain them.
# Send personalized offer to customer 3125 to retain them.
# Send personalized offer to customer 5355 to retain them.
# Send personalized offer to customer 6807 to retain them.
# Send personalized offer to customer 4239 to retain them.
# Send personalized offer to customer 4919 to retain them.
# Send personalized offer to customer 213 to retain them.
# Send personalized offer to customer 6119 to retain them.
# Send personalized offer to customer 230 to retain them.
# Send personalized offer to customer 6011 to retain them.
# Send personalized offer to customer 2584 to retain them.
# Send personalized offer to customer 5855 to retain them.
# Send personalized offer to customer 1755 to retain them.
# Send personalized offer to customer 1760 to retain them.
# Send personalized offer to customer 6086 to retain them.
# Send personalized offer to customer 2353 to retain them.
# Send personalized offer to customer 2051 to retain them.
# Send personalized offer to customer 1252 to retain them.
# Send personalized offer to customer 5883 to retain them.
# Send personalized offer to customer 1660 to retain them.
# Send personalized offer to customer 6771 to retain them.
# Send personalized offer to customer 503 to retain them.
# Send personalized offer to customer 6226 to retain them.
# Send personalized offer to customer 5774 to retain them.
# Send personalized offer to customer 4573 to retain them.
# Send personalized offer to customer 4018 to retain them.
# Send personalized offer to customer 5687 to retain them.
# Send personalized offer to customer 625 to retain them.
# Send personalized offer to customer 4165 to retain them.
# Send personalized offer to customer 6895 to retain them.
# Send personalized offer to customer 72 to retain them.
# Send personalized offer to customer 6111 to retain them.
# Send personalized offer to customer 2279 to retain them.
# Send personalized offer to customer 137 to retain them.
# Send personalized offer to customer 1789 to retain them.
# Send personalized offer to customer 5377 to retain them.
# Send personalized offer to customer 5676 to retain them.
# Send personalized offer to customer 6350 to retain them.
# Send personalized offer to customer 1842 to retain them.
# Send personalized offer to customer 3477 to retain them.
# Send personalized offer to customer 2537 to retain them.
# Send personalized offer to customer 6617 to retain them.
# Send personalized offer to customer 5578 to retain them.
# Send personalized offer to customer 1516 to retain them.
# Send personalized offer to customer 1685 to retain them.
# Send personalized offer to customer 4090 to retain them.
# Send personalized offer to customer 712 to retain them.
# Send personalized offer to customer 4813 to retain them.
# Send personalized offer to customer 2212 to retain them.
# Send personalized offer to customer 305 to retain them.
# Send personalized offer to customer 5856 to retain them.
# Send personalized offer to customer 5078 to retain them.
# Send personalized offer to customer 1089 to retain them.
# Send personalized offer to customer 4930 to retain them.
# Send personalized offer to customer 2926 to retain them.
# Send personalized offer to customer 3765 to retain them.
# Send personalized offer to customer 4069 to retain them.
# Send personalized offer to customer 4803 to retain them.
# Send personalized offer to customer 3177 to retain them.
# Send personalized offer to customer 5592 to retain them.
# Send personalized offer to customer 1746 to retain them.
# Send personalized offer to customer 3832 to retain them.
# Send personalized offer to customer 5793 to retain them.
# Send personalized offer to customer 3509 to retain them.
# Send personalized offer to customer 1120 to retain them.
# Send personalized offer to customer 1608 to retain them.
# Send personalized offer to customer 1691 to retain them.
# Send personalized offer to customer 3253 to retain them.
# Send personalized offer to customer 5486 to retain them.
# Send personalized offer to customer 2641 to retain them.
# Send personalized offer to customer 6619 to retain them.
# Send personalized offer to customer 1343 to retain them.
# Send personalized offer to customer 6373 to retain them.
# Send personalized offer to customer 120 to retain them.
# Send personalized offer to customer 6403 to retain them.
# Send personalized offer to customer 5829 to retain them.
# Send personalized offer to customer 5365 to retain them.
# Send personalized offer to customer 1871 to retain them.
# Send personalized offer to customer 640 to retain them.
# Send personalized offer to customer 3268 to retain them.
# Send personalized offer to customer 4231 to retain them.
# Send personalized offer to customer 4833 to retain them.
# Send personalized offer to customer 6116 to retain them.
# Send personalized offer to customer 2411 to retain them.
# Send personalized offer to customer 4587 to retain them.
# Send personalized offer to customer 5861 to retain them.
# Send personalized offer to customer 1550 to retain them.
# Send personalized offer to customer 4000 to retain them.
# Send personalized offer to customer 5000 to retain them.
# Send personalized offer to customer 6569 to retain them.
# Send personalized offer to customer 5072 to retain them.
# Send personalized offer to customer 3100 to retain them.
# Send personalized offer to customer 3659 to retain them.
# Send personalized offer to customer 341 to retain them.
# Send personalized offer to customer 5044 to retain them.
# Send personalized offer to customer 3366 to retain them.
# Send personalized offer to customer 6889 to retain them.
# Send personalized offer to customer 1190 to retain them.
# Send personalized offer to customer 4533 to retain them.
# Send personalized offer to customer 1281 to retain them.
# Send personalized offer to customer 1576 to retain them.
# Send personalized offer to customer 3291 to retain them.
# Send personalized offer to customer 3069 to retain them.
# Send personalized offer to customer 5550 to retain them.
# Send personalized offer to customer 4071 to retain them.
# Send personalized offer to customer 6218 to retain them.
# Send personalized offer to customer 5563 to retain them.
# Send personalized offer to customer 1415 to retain them.
# Send personalized offer to customer 6531 to retain them.
# Send personalized offer to customer 1698 to retain them.
# Send personalized offer to customer 721 to retain them.
# Send personalized offer to customer 2091 to retain them.
# Send personalized offer to customer 5616 to retain them.
# Send personalized offer to customer 4374 to retain them.
# Send personalized offer to customer 1857 to retain them.
# Send personalized offer to customer 395 to retain them.
# Send personalized offer to customer 2958 to retain them.
# Send personalized offer to customer 1440 to retain them.
# Send personalized offer to customer 5095 to retain them.
# Send personalized offer to customer 2759 to retain them.
# Send personalized offer to customer 7042 to retain them.
# Send personalized offer to customer 6359 to retain them.
# Send personalized offer to customer 3916 to retain them.
# Send personalized offer to customer 3812 to retain them.
# Send personalized offer to customer 2793 to retain them.
# Send personalized offer to customer 2855 to retain them.
# Send personalized offer to customer 1080 to retain them.
# Send personalized offer to customer 2809 to retain them.
# Send personalized offer to customer 3475 to retain them.
# Send personalized offer to customer 3612 to retain them.
# Send personalized offer to customer 1811 to retain them.
# Send personalized offer to customer 744 to retain them.
# Send personalized offer to customer 5199 to retain them.
# Send personalized offer to customer 2216 to retain them.
# Send personalized offer to customer 4878 to retain them.
# Send personalized offer to customer 2944 to retain them.
# Send personalized offer to customer 738 to retain them.
# Send personalized offer to customer 4840 to retain them.
# Send personalized offer to customer 5314 to retain them.
# Send personalized offer to customer 5083 to retain them.
# Send personalized offer to customer 4009 to retain them.
# Send personalized offer to customer 3341 to retain them.
# Send personalized offer to customer 6835 to retain them.
# Send personalized offer to customer 4761 to retain them.
# Send personalized offer to customer 5929 to retain them.
# Send personalized offer to customer 2195 to retain them.
# Send personalized offer to customer 2512 to retain them.
# Send personalized offer to customer 1504 to retain them.
# Send personalized offer to customer 482 to retain them.
# Send personalized offer to customer 242 to retain them.
# Send personalized offer to customer 946 to retain them.
# Send personalized offer to customer 5466 to retain them.
# Send personalized offer to customer 4208 to retain them.
# Send personalized offer to customer 1345 to retain them.
# Send personalized offer to customer 2808 to retain them.
# Send personalized offer to customer 683 to retain them.
# Send personalized offer to customer 3151 to retain them.
# Send personalized offer to customer 3820 to retain them.
# Send personalized offer to customer 6651 to retain them.
# Send personalized offer to customer 2845 to retain them.
# Send personalized offer to customer 411 to retain them.
# Send personalized offer to customer 222 to retain them.
# Send personalized offer to customer 3174 to retain them.
# Send personalized offer to customer 142 to retain them.
# Send personalized offer to customer 5056 to retain them.
# Send personalized offer to customer 4884 to retain them.
# Send personalized offer to customer 4350 to retain them.
# Send personalized offer to customer 337 to retain them.
# Send personalized offer to customer 5262 to retain them.
# Send personalized offer to customer 5999 to retain them.
# Send personalized offer to customer 3465 to retain them.
# Send personalized offer to customer 5982 to retain them.
# Send personalized offer to customer 405 to retain them.
# Send personalized offer to customer 1142 to retain them.
# Send personalized offer to customer 3114 to retain them.
# Send personalized offer to customer 6059 to retain them.
# Send personalized offer to customer 3626 to retain them.
# Send personalized offer to customer 6957 to retain them.
# Send personalized offer to customer 1817 to retain them.
# Send personalized offer to customer 5552 to retain them.
# Send personalized offer to customer 5612 to retain them.
# Send personalized offer to customer 2112 to retain them.
# Send personalized offer to customer 491 to retain them.
# Send personalized offer to customer 6156 to retain them.
# Send personalized offer to customer 3379 to retain them.
# Send personalized offer to customer 3491 to retain them.
# Send personalized offer to customer 617 to retain them.
# Send personalized offer to customer 3230 to retain them.
# Send personalized offer to customer 6547 to retain them.
# Send personalized offer to customer 2905 to retain them.
# Send personalized offer to customer 1557 to retain them.
# Send personalized offer to customer 793 to retain them.
# Send personalized offer to customer 5757 to retain them.
# Send personalized offer to customer 5997 to retain them.
# Send personalized offer to customer 5402 to retain them.
# Send personalized offer to customer 2961 to retain them.
# Send personalized offer to customer 3870 to retain them.
# Send personalized offer to customer 3836 to retain them.
# Send personalized offer to customer 5280 to retain them.
# Send personalized offer to customer 1703 to retain them.
# Send personalized offer to customer 3109 to retain them.
# Send personalized offer to customer 6248 to retain them.
# Send personalized offer to customer 2843 to retain them.
# Send personalized offer to customer 1286 to retain them.
# Send personalized offer to customer 5035 to retain them.
# Send personalized offer to customer 4024 to retain them.
# Send personalized offer to customer 5821 to retain them.
# Send personalized offer to customer 344 to retain them.
# Send personalized offer to customer 3992 to retain them.
# Send personalized offer to customer 6410 to retain them.
# Send personalized offer to customer 577 to retain them.
# Send personalized offer to customer 1153 to retain them.
# Send personalized offer to customer 5572 to retain them.
# Send personalized offer to customer 257 to retain them.
# Send personalized offer to customer 5203 to retain them.
# Send personalized offer to customer 1831 to retain them.
# Send personalized offer to customer 1353 to retain them.
# Send personalized offer to customer 1260 to retain them.
# Send personalized offer to customer 2840 to retain them.
# Send personalized offer to customer 514 to retain them.
# Send personalized offer to customer 5269 to retain them.
# Send personalized offer to customer 1901 to retain them.
# Send personalized offer to customer 4123 to retain them.
# Send personalized offer to customer 5674 to retain them.
# Send personalized offer to customer 6083 to retain them.
# Send personalized offer to customer 3259 to retain them.
# Send personalized offer to customer 3665 to retain them.
# Send personalized offer to customer 2058 to retain them.
# Send personalized offer to customer 5459 to retain them.
# Send personalized offer to customer 6928 to retain them.
# Send personalized offer to customer 112 to retain them.
# Send personalized offer to customer 6056 to retain them.
# Send personalized offer to customer 121 to retain them.
# Send personalized offer to customer 2830 to retain them.
# Send personalized offer to customer 2434 to retain them.
# Send personalized offer to customer 2490 to retain them.
# Send personalized offer to customer 929 to retain them.
# Send personalized offer to customer 5507 to retain them.
# Send personalized offer to customer 3951 to retain them.
# Send personalized offer to customer 4372 to retain them.
# Send personalized offer to customer 4434 to retain them.
# Send personalized offer to customer 1540 to retain them.
# Send personalized offer to customer 6656 to retain them.
# Send personalized offer to customer 3712 to retain them.
# Send personalized offer to customer 819 to retain them.
# Send personalized offer to customer 2541 to retain them.
# Send personalized offer to customer 6115 to retain them.
# Send personalized offer to customer 5723 to retain them.
# Send personalized offer to customer 265 to retain them.
# Send personalized offer to customer 5084 to retain them.
# Send personalized offer to customer 2341 to retain them.
# Send personalized offer to customer 2177 to retain them.
# Send personalized offer to customer 6561 to retain them.
# Send personalized offer to customer 3088 to retain them.
# Send personalized offer to customer 3564 to retain them.
# Send personalized offer to customer 5532 to retain them.
# Send personalized offer to customer 2449 to retain them.
# Send personalized offer to customer 68 to retain them.
# Send personalized offer to customer 1104 to retain them.
# Send personalized offer to customer 1877 to retain them.
# Send personalized offer to customer 2724 to retain them.
# Send personalized offer to customer 4590 to retain them.
# Send personalized offer to customer 4865 to retain them.
# Send personalized offer to customer 4432 to retain them.
# Send personalized offer to customer 4057 to retain them.
# Send personalized offer to customer 4181 to retain them.
# Send personalized offer to customer 2978 to retain them.
# Send personalized offer to customer 541 to retain them.
# Send personalized offer to customer 1715 to retain them.
# Send personalized offer to customer 5171 to retain them.
# Send personalized offer to customer 7033 to retain them.
# Send personalized offer to customer 4306 to retain them.
# Send personalized offer to customer 6416 to retain them.
# Send personalized offer to customer 4312 to retain them.
# Send personalized offer to customer 4952 to retain them.
# Send personalized offer to customer 5866 to retain them.
# Send personalized offer to customer 6852 to retain them.
# Send personalized offer to customer 1406 to retain them.
# Send personalized offer to customer 1400 to retain them.
# Send personalized offer to customer 5801 to retain them.
# Send personalized offer to customer 1801 to retain them.
# Send personalized offer to customer 3961 to retain them.
# Send personalized offer to customer 4477 to retain them.
# Send personalized offer to customer 537 to retain them.
# Send personalized offer to customer 5918 to retain them.
# Send personalized offer to customer 2076 to retain them.
# Send personalized offer to customer 2203 to retain them.
# Send personalized offer to customer 5672 to retain them.
# Send personalized offer to customer 2326 to retain them.
# Send personalized offer to customer 6397 to retain them.
# Send personalized offer to customer 2278 to retain them.
# Send personalized offer to customer 3655 to retain them.
# Send personalized offer to customer 2484 to retain them.
# Send personalized offer to customer 1666 to retain them.
# Send personalized offer to customer 963 to retain them.
# Send personalized offer to customer 2080 to retain them.
# Send personalized offer to customer 6431 to retain them.
# Send personalized offer to customer 1475 to retain them.
# Send personalized offer to customer 3163 to retain them.
# Send personalized offer to customer 831 to retain them.
# Send personalized offer to customer 5322 to retain them.
# Send personalized offer to customer 2786 to retain them.
# Send personalized offer to customer 6630 to retain them.
# Send personalized offer to customer 1300 to retain them.
# Send personalized offer to customer 1445 to retain them.
# Send personalized offer to customer 1082 to retain them.
# Send personalized offer to customer 5104 to retain them.
# Send personalized offer to customer 399 to retain them.
# Send personalized offer to customer 1002 to retain them.
# Send personalized offer to customer 5534 to retain them.
# Send personalized offer to customer 2217 to retain them.
# Send personalized offer to customer 1649 to retain them.
# Send personalized offer to customer 3414 to retain them.
# Send personalized offer to customer 33 to retain them.
# Send personalized offer to customer 4392 to retain them.
# Send personalized offer to customer 1160 to retain them.
# Send personalized offer to customer 4688 to retain them.
# Send personalized offer to customer 6439 to retain them.
# Send personalized offer to customer 5124 to retain them.
# Send personalized offer to customer 3182 to retain them.
# Send personalized offer to customer 3902 to retain them.
# Send personalized offer to customer 1896 to retain them.
# Send personalized offer to customer 5192 to retain them.
# Send personalized offer to customer 3148 to retain them.
# Send personalized offer to customer 3487 to retain them.
# Send personalized offer to customer 2131 to retain them.
# Send personalized offer to customer 3747 to retain them.
# Send personalized offer to customer 4886 to retain them.
# Send personalized offer to customer 1565 to retain them.
# Send personalized offer to customer 1560 to retain them.
# Send personalized offer to customer 3735 to retain them.
# Send personalized offer to customer 3979 to retain them.
# Send personalized offer to customer 2996 to retain them.
# Send personalized offer to customer 4327 to retain them.
# Send personalized offer to customer 1744 to retain them.
# Send personalized offer to customer 6882 to retain them.
# Send personalized offer to customer 1583 to retain them.
# Send personalized offer to customer 4727 to retain them.
# Send personalized offer to customer 6445 to retain them.
# Send personalized offer to customer 3862 to retain them.
# Send personalized offer to customer 3363 to retain them.
# Send personalized offer to customer 4008 to retain them.
# Send personalized offer to customer 6880 to retain them.
# Send personalized offer to customer 2624 to retain them.
# Send personalized offer to customer 3604 to retain them.
# Send personalized offer to customer 2261 to retain them.
# Send personalized offer to customer 3929 to retain them.
# Send personalized offer to customer 1903 to retain them.
# Send personalized offer to customer 2327 to retain them.
# Send personalized offer to customer 423 to retain them.
# Send personalized offer to customer 1978 to retain them.
# Send personalized offer to customer 5460 to retain them.
# Send personalized offer to customer 1599 to retain them.
# Send personalized offer to customer 6925 to retain them.
# Send personalized offer to customer 1490 to retain them.
# Send personalized offer to customer 4250 to retain them.
# Send personalized offer to customer 2499 to retain them.
# Send personalized offer to customer 4765 to retain them.
# Send personalized offer to customer 1589 to retain them.
# Send personalized offer to customer 4636 to retain them.
# Send personalized offer to customer 2626 to retain them.
# Send personalized offer to customer 5158 to retain them.
# Send personalized offer to customer 109 to retain them.
# Send personalized offer to customer 1539 to retain them.
# Send personalized offer to customer 1237 to retain them.
# Send personalized offer to customer 4659 to retain them.
# Send personalized offer to customer 5068 to retain them.
# Send personalized offer to customer 5106 to retain them.
# Send personalized offer to customer 1277 to retain them.
# Send personalized offer to customer 1544 to retain them.
# Send personalized offer to customer 1226 to retain them.
# Send personalized offer to customer 707 to retain them.
# Send personalized offer to customer 3973 to retain them.
# Send personalized offer to customer 6279 to retain them.
# Send personalized offer to customer 4894 to retain them.
# Send personalized offer to customer 750 to retain them.
# Send personalized offer to customer 2531 to retain them.
# Send personalized offer to customer 4173 to retain them.
# Send personalized offer to customer 616 to retain them.
# Send personalized offer to customer 4786 to retain them.
# Send personalized offer to customer 4519 to retain them.
# Send personalized offer to customer 4251 to retain them.
# Send personalized offer to customer 4013 to retain them.
# Send personalized offer to customer 4168 to retain them.
# Send personalized offer to customer 5416 to retain them.
# Send personalized offer to customer 821 to retain them.
# Send personalized offer to customer 5768 to retain them.
# Send personalized offer to customer 2355 to retain them.
# Send personalized offer to customer 4252 to retain them.
# Send personalized offer to customer 1594 to retain them.
# Send personalized offer to customer 4291 to retain them.
# Send personalized offer to customer 45 to retain them.
# Send personalized offer to customer 1936 to retain them.
# Send personalized offer to customer 4126 to retain them.
# Send personalized offer to customer 4830 to retain them.
# Send personalized offer to customer 2702 to retain them.
# Send personalized offer to customer 6927 to retain them.
# Send personalized offer to customer 1357 to retain them.
# Send personalized offer to customer 3931 to retain them.
# Send personalized offer to customer 6383 to retain them.
# Send personalized offer to customer 3113 to retain them.
# Send personalized offer to customer 909 to retain them.
# Send personalized offer to customer 1709 to retain them.
# Send personalized offer to customer 1623 to retain them.
# Send personalized offer to customer 3315 to retain them.
# Send personalized offer to customer 4011 to retain them.
# Send personalized offer to customer 2966 to retain them.
# Send personalized offer to customer 6854 to retain them.
# Send personalized offer to customer 2599 to retain them.
# Send personalized offer to customer 5844 to retain them.
# Send personalized offer to customer 6844 to retain them.
# Send personalized offer to customer 3882 to retain them.
# Send personalized offer to customer 6230 to retain them.
# Send personalized offer to customer 4068 to retain them.
# Send personalized offer to customer 1387 to retain them.
# Send personalized offer to customer 3793 to retain them.
# Send personalized offer to customer 4412 to retain them.
# Send personalized offer to customer 7031 to retain them.
# Send personalized offer to customer 4403 to retain them.
# Send personalized offer to customer 5998 to retain them.
# Send personalized offer to customer 1279 to retain them.
# Send personalized offer to customer 874 to retain them.
# Send personalized offer to customer 3198 to retain them.
# Send personalized offer to customer 4145 to retain them.
# Send personalized offer to customer 199 to retain them.
# Send personalized offer to customer 35 to retain them.
# Send personalized offer to customer 277 to retain them.
# Send personalized offer to customer 6870 to retain them.
# Send personalized offer to customer 79 to retain them.
# Send personalized offer to customer 6787 to retain them.
# Send personalized offer to customer 904 to retain them.
# Send personalized offer to customer 4285 to retain them.
# Send personalized offer to customer 5902 to retain them.
# Send personalized offer to customer 4820 to retain them.
# Send personalized offer to customer 2746 to retain them.
# Send personalized offer to customer 1451 to retain them.
# Send personalized offer to customer 1446 to retain them.
# Send personalized offer to customer 4104 to retain them.
# Send personalized offer to customer 5188 to retain them.
# Send personalized offer to customer 1754 to retain them.
# Send personalized offer to customer 921 to retain them.
# Send personalized offer to customer 2362 to retain them.
# Send personalized offer to customer 2992 to retain them.
# Send personalized offer to customer 3989 to retain them.
# Send personalized offer to customer 1906 to retain them.
# Send personalized offer to customer 6779 to retain them.
# Send personalized offer to customer 1884 to retain them.
# Send personalized offer to customer 4419 to retain them.
# Send personalized offer to customer 1379 to retain them.
# Send personalized offer to customer 3935 to retain them.
# Send personalized offer to customer 6233 to retain them.
# Send personalized offer to customer 6755 to retain them.
# Send personalized offer to customer 2171 to retain them.
# Send personalized offer to customer 1700 to retain them.
# Send personalized offer to customer 1667 to retain them.
# Send personalized offer to customer 6274 to retain them.
# Send personalized offer to customer 4566 to retain them.
# Send personalized offer to customer 2120 to retain them.
# Send personalized offer to customer 5220 to retain them.
# Send personalized offer to customer 2425 to retain them.
# Send personalized offer to customer 694 to retain them.
# Send personalized offer to customer 3574 to retain them.
# Send personalized offer to customer 1695 to retain them.
# Send personalized offer to customer 6425 to retain them.
# Send personalized offer to customer 4046 to retain them.
# Send personalized offer to customer 4414 to retain them.
# Send personalized offer to customer 1511 to retain them.
# Send personalized offer to customer 3628 to retain them.
# Send personalized offer to customer 6994 to retain them.
# Send personalized offer to customer 957 to retain them.
# Send personalized offer to customer 4559 to retain them.
# Send personalized offer to customer 5505 to retain them.
# Send personalized offer to customer 6669 to retain them.
# Send personalized offer to customer 2628 to retain them.
# Send personalized offer to customer 3451 to retain them.
# Send personalized offer to customer 696 to retain them.
# Send personalized offer to customer 1193 to retain them.
# Send personalized offer to customer 4852 to retain them.
# Send personalized offer to customer 6194 to retain them.
# Send personalized offer to customer 250 to retain them.
# Send personalized offer to customer 2555 to retain them.
# Send personalized offer to customer 886 to retain them.
# Send personalized offer to customer 4767 to retain them.
# Send personalized offer to customer 6747 to retain them.
# Send personalized offer to customer 5958 to retain them.
# Send personalized offer to customer 357 to retain them.
# Send personalized offer to customer 5239 to retain them.
# Send personalized offer to customer 5775 to retain them.
# Send personalized offer to customer 3180 to retain them.
# Send personalized offer to customer 4609 to retain them.
# Send personalized offer to customer 118 to retain them.
# Send personalized offer to customer 3171 to retain them.
# Send personalized offer to customer 3607 to retain them.
# Send personalized offer to customer 4116 to retain them.
# Send personalized offer to customer 6735 to retain them.
# Send personalized offer to customer 4029 to retain them.
# Send personalized offer to customer 2622 to retain them.
# Send personalized offer to customer 4729 to retain them.
# Send personalized offer to customer 4144 to retain them.
# Send personalized offer to customer 3656 to retain them.
# Send personalized offer to customer 795 to retain them.
# Send personalized offer to customer 1321 to retain them.
# Send personalized offer to customer 1322 to retain them.
# Send personalized offer to customer 686 to retain them.
# Send personalized offer to customer 6938 to retain them.
# Send personalized offer to customer 3625 to retain them.
# Send personalized offer to customer 1203 to retain them.
# Send personalized offer to customer 2951 to retain them.
# Send personalized offer to customer 2380 to retain them.
# Send personalized offer to customer 4756 to retain them.
# Send personalized offer to customer 2999 to retain them.
# Send personalized offer to customer 2435 to retain them.
# Send personalized offer to customer 30 to retain them.
# Send personalized offer to customer 6320 to retain them.
# Send personalized offer to customer 2055 to retain them.
# Send personalized offer to customer 6381 to retain them.
# Send personalized offer to customer 3794 to retain them.

# %%
def encourage_long_term_contract(customer_id):
    print(f"Offer a discount for an annual subscription to customer {customer_id}.")

def promote_value_added_services(customer_id):
    print(f"Promote premium content to customer {customer_id}.")

def create_targeted_marketing_campaign(customer_id):
    print(f"Send a personalized marketing campaign to customer {customer_id}.")

def gather_feedback_and_act(customer_id, feedback):
    print(f"Collect feedback from customer {customer_id} and take action: {feedback}")

def enhance_customer_engagement(customer_id):
    print(f"Enhance customer engagement for customer {customer_id}.")

def monitor_and_adjust_strategies():

    print("Monitor churn rates and adjust retention strategies as needed.")

def competitive_analysis():
    print("Conduct competitive analysis to stay competitive in the market.")

for customer_id, churn_probability in zip(X_test.index, high_risk_customers):
    if churn_probability > 0.5:
        encourage_long_term_contract(customer_id)
        promote_value_added_services(customer_id)
        create_targeted_marketing_campaign(customer_id)
        gather_feedback_and_act(customer_id, "Customer expressed concerns about pricing.")
        enhance_customer_engagement(customer_id)

monitor_and_adjust_strategies()

competitive_analysis()
# Out:
# Offer a discount for an annual subscription to customer 3678.
# Promote premium content to customer 3678.
# Send a personalized marketing campaign to customer 3678.
# Collect feedback from customer 3678 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 3678.
# Offer a discount for an annual subscription to customer 4060.
# Promote premium content to customer 4060.
# Send a personalized marketing campaign to customer 4060.
# Collect feedback from customer 4060 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 4060.
# Offer a discount for an annual subscription to customer 5007.
# Promote premium content to customer 5007.
# Send a personalized marketing campaign to customer 5007.
# Collect feedback from customer 5007 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 5007.
# Offer a discount for an annual subscription to customer 2603.
# Promote premium content to customer 2603.
# Send a personalized marketing campaign to customer 2603.
# Collect feedback from customer 2603 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 2603.
# Offer a discount for an annual subscription to customer 6910.
# Promote premium content to customer 6910.
# Send a personalized marketing campaign to customer 6910.
# Collect feedback from customer 6910 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 6910.
# Offer a discount for an annual subscription to customer 1672.
# Promote premium content to customer 1672.
# Send a personalized marketing campaign to customer 1672.
# Collect feedback from customer 1672 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 1672.
# Offer a discount for an annual subscription to customer 4176.
# Promote premium content to customer 4176.
# Send a personalized marketing campaign to customer 4176.
# Collect feedback from customer 4176 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 
and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 5281.
# Offer a discount for an annual subscription to customer 671.
# Promote premium content to customer 671.
# Send a personalized marketing campaign to customer 671.
# Collect feedback from customer 671 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 671.
# Offer a discount for an annual subscription to customer 194.
# Promote premium content to customer 194.
# Send a personalized marketing campaign to customer 194.
# Collect feedback from customer 194 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 194.
# Offer a discount for an annual subscription to customer 3701.
# Promote premium content to customer 3701.
# Send a personalized marketing campaign to customer 3701.
# Collect feedback from customer 3701 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 3701.
# Offer a discount for an annual subscription to customer 3449.
# Promote premium content to customer 3449.
# Send a personalized marketing campaign to customer 3449.
# Collect feedback from customer 3449 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 3449.
# Offer a discount for an annual subscription to customer 1221.
# Promote premium content to customer 1221.
# Send a personalized marketing campaign to customer 1221.
# Collect feedback from customer 1221 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 1221.
# Offer a discount for an annual subscription to customer 2240.
# Promote premium content to customer 2240.
# Send a personalized marketing campaign to customer 2240.
# Collect feedback from customer 2240 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 2240.
# Offer a discount for an annual subscription to customer 6960.
# Promote premium content to customer 6960.
# Send a personalized marketing campaign to customer 6960.
# Collect feedback from customer 6960 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 6960.
# Offer a discount for an annual subscription to customer 3314.
# Promote premium content to customer 3314.
# Send a personalized marketing campaign to customer 3314.
# Collect feedback from customer 3314 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 3314.
# Offer a discount for an annual subscription to customer 3321.
# Promote premium content to customer 3321.
# Send a personalized marketing campaign to customer 3321.
# Collect feedback from customer 3321 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 3321.
# Offer a discount for an annual subscription to customer 6798.
# Promote premium content to customer 6798.
# Send a personalized marketing campaign to customer 6798.
# Collect feedback from customer 6798 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 6798.
# Offer a discount for an annual subscription to customer 604.
# Promote premium content to customer 604.
# Send a personalized marketing campaign to customer 604.
# Collect feedback from customer 604 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 604.
# Offer a discount for an annual subscription to customer 6454.
# Promote premium content to customer 6454.
# Send a personalized marketing campaign to customer 6454.
# Collect feedback from customer 6454 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 6454.
# Offer a discount for an annual subscription to customer 6200.
# Promote premium content to customer 6200.
# Send a personalized marketing campaign to customer 6200.
# Collect feedback from customer 6200 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 6200.
# Offer a discount for an annual subscription to customer 2937.
# Promote premium content to customer 2937.
# Send a personalized marketing campaign to customer 2937.
# Collect feedback from customer 2937 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 2937.
# Offer a discount for an annual subscription to customer 6977.
# Promote premium content to customer 6977.
# Send a personalized marketing campaign to customer 6977.
# Collect feedback from customer 6977 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 6977.
# Offer a discount for an annual subscription to customer 3220.
# Promote premium content to customer 3220.
# Send a personalized marketing campaign to customer 3220.
# Collect feedback from customer 3220 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 3220.
# Offer a discount for an annual subscription to customer 1017.
# Promote premium content to customer 1017.
# Send a personalized marketing campaign to customer 1017.
# Collect feedback from customer 1017 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 1017.
# Offer a discount for an annual subscription to customer 3860.
# Promote premium content to customer 3860.
# Send a personalized marketing campaign to customer 3860.
# Collect feedback from customer 3860 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 3860.
# Offer a discount for an annual subscription to customer 1290.
# Promote premium content to customer 1290.
# Send a personalized marketing campaign to customer 1290.
# Collect feedback from customer 1290 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 1290.
# Offer a discount for an annual subscription to customer 4861.
# Promote premium content to customer 4861.
# Send a personalized marketing campaign to customer 4861.
# Collect feedback from customer 4861 and take action: Customer expressed concerns about pricing.
# Enhance customer engagement for customer 